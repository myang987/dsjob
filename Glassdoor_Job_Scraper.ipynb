# %%
# Install packages

#import sys
#!{sys.executable} -m pip install selenium
#!{sys.executable} -m pip install webdriver_manager

# %%
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd
import re
import numpy as np

# %%
service=Service(ChromeDriverManager().install())

# %%
def get_jobs(keyword, location, num_jobs, verbose, slp_time):
    
    '''Gathers jobs as a dataframe, scraped from Glassdoor'''
    
    jobs = []
    #Initializing the webdriver
    options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    #options.add_argument('headless')
    
    #Change the path to where chromedriver is in your home folder by changing service=(addres)
    #Chrome driver is being installed everytime the kernel is restart and saved as variable, 
    #not needing to provide location path
    driver = webdriver.Chrome(service=service, options=options)
    driver.set_window_size(1120, 1000)
    
    # Glassdoor website URL
    # This program only works for US and Canada due to glassdoor requiring location id for proper search
    if location.lower() == 'canada':
        # Below is the url location tags for jobs in Canada
        loc = "&locT=N&locId=3&locName=Canada"
    elif location.lower() == 'us' or location.lower() == 'usa':
        # Below is the url location tags for jobs in US
        loc = "&locT=N&cId=1&locName=United%20States"
    else:
        print("Invalid Location: Canada or US only")
        return pd.DataFrame(jobs)
    
    url = "https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword="+keyword+"&sc.keyword="+keyword+loc+"&jobType="
    #url = 'https://www.glassdoor.com/Job/jobs.htm?sc.keyword="' + keyword + '"&locT=C&locId=1147401&locKeyword=San%20Francisco,%20CA&jobType=all&fromAge=-1&minSalary=0&includeNoSalaryJobs=true&radius=100&cityId=-1&minRating=0.0&industryId=-1&sgocId=-1&seniorityType=all&companyId=-1&employerSizes=0&applicationType=0&remoteWorkType=0'
    driver.get(url)
    

    #If true, should be still looking for new jobs.
    while len(jobs) < num_jobs:  

        #Let the page load. Change this number based on your internet speed.
        #Or, wait until the webpage is loaded, instead of hardcoding it.
        time.sleep(slp_time)

        #Test for the "Sign Up" prompt and get rid of it.
        try:
            driver.find_element(By.CLASS_NAME,"selected").click()
        except ElementClickInterceptedException:
            pass

        time.sleep(1)

        try:
            driver.find_element(By.CSS_SELECTOR,'[alt="Close"]').click() #clicking to the X.
            print(' x out worked')
        except NoSuchElementException:
            print(' x out failed')
            pass

        
        #Gather all the job node elements from the left column of Glassdoor
        #These are the buttons we're going to click.
        job_buttons = driver.find_elements(By.XPATH, "//article[@id='MainCol']//ul/li[starts-with(@class, 'react-job-listing')]")  
        
        for job_button in job_buttons:  
            
            print("Progress: {}".format("" + str(len(jobs)) + "/" + str(num_jobs)))
            if len(jobs) >= num_jobs:
                break

            #Click on each job node element
            webdriver.ActionChains(driver).move_to_element(job_button).click(job_button).perform()
            
            time.sleep(1)
            collected_successfully = False
            
            #Gather the basic information from the loaded job posting main page
            while not collected_successfully:
                try:
                    try:
                        company_name = driver.find_element(By.XPATH, './/div[@data-test="employerName"]').text
                    except NoSuchElementException:
                        company_name = -1
                    try:
                        division = driver.find_element(By.XPATH, './/div[@class="division"]').text
                    except NoSuchElementException:
                        division = -1
                    try:
                        location = driver.find_element(By.XPATH, './/div[@data-test="location"]').text
                    except NoSuchElementException:
                        location = -1
                    try:
                        job_title = driver.find_element(By.XPATH, './/div[@data-test="jobTitle"]').text
                    except NoSuchElementException:
                        job_title = -1
                    try:
                        job_description = driver.find_element(By.XPATH, './/div[@class="jobDescriptionContent desc"]').text
                    except NoSuchElementException:
                        job_description = -1
                        
                    collected_successfully = True
                except:
                    time.sleep(5)

            try:
                #Glassdoor salary estimate
                salary_estimate = job_button.find_element(By.XPATH, './/span[@data-test="detailSalary"]').text
            except NoSuchElementException:
                salary_estimate = -1 #You need to set a "not found value. It's important."
            
            try:
                #Glassdoor employer review rating score
                rating = driver.find_element(By.XPATH, './/div[@id="employerStats"]/div[1]/div').text
            except NoSuchElementException:
                rating = -1 #You need to set a "not found value. It's important."

            #Printing for debugging
            if verbose:
                print("Job Title: {}".format(job_title))
                print("Salary Estimate: {}".format(salary_estimate))
                print("Job Description: {}".format(job_description[:500]))
                print("Rating: {}".format(rating))
                print("Company Name: {}".format(company_name))
                print("Division: {}".format(division))
                print("Location: {}".format(location))


            #Gather additional information about the company from Glassdoor company overview section
            try:
                driver.find_element(By.XPATH, './/div[@id="CompanyContainer"]')

                try:
                    size = driver.find_element(By.XPATH, './/*[@id="EmpBasicInfo"]//div[span/text()="Size"]/span[2]').text
                except NoSuchElementException:
                    size = -1

                try:
                    founded = driver.find_element(By.XPATH, './/*[@id="EmpBasicInfo"]//div[span/text()="Founded"]/span[2]').text
                except NoSuchElementException:
                    founded = -1

                try:
                    type_of_ownership = driver.find_element(By.XPATH, './/*[@id="EmpBasicInfo"]//div[span/text()="Type"]/span[2]').text
                except NoSuchElementException:
                    type_of_ownership = -1

                try:
                    industry = driver.find_element(By.XPATH, './/*[@id="EmpBasicInfo"]//div[span/text()="Industry"]/span[2]').text
                except NoSuchElementException:
                    industry = -1

                try:
                    sector = driver.find_element(By.XPATH, './/*[@id="EmpBasicInfo"]//div[span/text()="Sector"]/span[2]').text
                except NoSuchElementException:
                    sector = -1

                try:
                    revenue = driver.find_element(By.XPATH, './/*[@id="EmpBasicInfo"]//div[span/text()="Revenue"]/span[2]').text
                except NoSuchElementException:
                    revenue = -1


            except NoSuchElementException:  #Rarely, some job postings do not have the "Company" tab.
                size = -1
                founded = -1
                type_of_ownership = -1
                industry = -1
                sector = -1
                revenue = -1

                
            if verbose:
                print("Size: {}".format(size))
                print("Founded: {}".format(founded))
                print("Type of Ownership: {}".format(type_of_ownership))
                print("Industry: {}".format(industry))
                print("Sector: {}".format(sector))
                print("Revenue: {}".format(revenue))
                print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")

            jobs.append({"Job Title" : job_title,
            "Salary Estimate" : salary_estimate,
            "Job Description" : job_description,
            "Rating" : float(rating),
            "Company Name" : company_name,
            "Division" : division,             
            "Location" : location,
            "Size" : size,
            "Founded" : int(founded),
            "Type of ownership" : type_of_ownership,
            "Industry" : industry,
            "Sector" : sector,
            "Revenue" : revenue})
            #add job to jobs
                
        #Clicking on the "next page" button
        try:
            driver.find_element(By.XPATH, "//article[@id='MainCol']//button[starts-with(@class, 'nextButton')]").click()
        except NoSuchElementException:
            print("Scraping terminated before reaching target number of jobs. Needed {}, got {}.".format(num_jobs, len(jobs)))
            break
   
    return pd.DataFrame(jobs)  #This line converts the dictionary object into a pandas DataFrame.

# %%
# Can change the salary part to get the entire range estimate rather than average
# Company descriptors do not necessarily include the same factors listed (line 113-145)
# As the section uses div indexing, the values may not match with correct column
# Can instead perform an evaluation based on the sub-heading

# https://stackoverflow.com/questions/3655549/xpath-containstext-some-string-doesnt-work-when-used-with-node-with-more
# //*[contains(text(),'ABC')]

# try:
#    driver.findElement.textcontains('industry')
#    try:
#        industry = driver.findElement(industry).text
#    except NoSuchElementException:
#        industry = None
# except NoSuchElementException:
#     industry = None

# %%
# Change the location keyword to either "canada" or "us"

df = get_jobs('data scientist','canada',35, False, 15)
#df = get_jobs('data scientist','canada',1000, False, 15)

df.to_csv('glassdoor_jobs.csv', index = False)
# Out:
#  x out failed
# Progress: 0/150
# Progress: 1/150
# Progress: 2/150
# Progress: 3/150
# Progress: 4/150
# Progress: 5/150
# Progress: 6/150
# Progress: 7/150
# Progress: 8/150
# Progress: 9/150
# Progress: 10/150
# Progress: 11/150
# Progress: 12/150
# Progress: 13/150
# Progress: 14/150
# Progress: 15/150
# Progress: 16/150
# Progress: 17/150
# Progress: 18/150
# Progress: 19/150
# Progress: 20/150
# Progress: 21/150
# Progress: 22/150
# Progress: 23/150
# Progress: 24/150
# Progress: 25/150
# Progress: 26/150
# Progress: 27/150
# Progress: 28/150
# Progress: 29/150
#  x out failed
# Progress: 30/150
# Progress: 31/150
# Progress: 32/150
# Progress: 33/150
# Progress: 34/150
# Progress: 35/150
# Progress: 36/150
# Progress: 37/150
# Progress: 38/150
# Progress: 39/150
# Progress: 40/150
# Progress: 41/150
# Progress: 42/150
# Progress: 43/150
# Progress: 44/150
# Progress: 45/150
# Progress: 46/150
# Progress: 47/150
# Progress: 48/150
# Progress: 49/150
# Progress: 50/150
# Progress: 51/150
# Progress: 52/150
# Progress: 53/150
# Progress: 54/150
# Progress: 55/150
# Progress: 56/150
# Progress: 57/150
# Progress: 58/150
# Progress: 59/150
#  x out failed
# Progress: 60/150
# Progress: 61/150
# Progress: 62/150
# Progress: 63/150
# Progress: 64/150
# Progress: 65/150
# Progress: 66/150
# Progress: 67/150
# Progress: 68/150
# Progress: 69/150
# Progress: 70/150
# Progress: 71/150
# Progress: 72/150
# Progress: 73/150
# Progress: 74/150
# Progress: 75/150
# Progress: 76/150
# Progress: 77/150
# Progress: 78/150
# Progress: 79/150
# Progress: 80/150
# Progress: 81/150
# Progress: 82/150
# Progress: 83/150
# Progress: 84/150
# Progress: 85/150
# Progress: 86/150
# Progress: 87/150
# Progress: 88/150
# Progress: 89/150
#  x out failed
# Progress: 90/150
# Progress: 91/150
# Progress: 92/150
# Progress: 93/150
# Progress: 94/150
# Progress: 95/150
# Progress: 96/150
# Progress: 97/150
# Progress: 98/150
# Progress: 99/150
# Progress: 100/150
# Progress: 101/150
# Progress: 102/150
# Progress: 103/150
# Progress: 104/150
# Progress: 105/150
# Progress: 106/150
# Progress: 107/150
# Progress: 108/150
# Progress: 109/150
# Progress: 110/150
# Progress: 111/150
# Progress: 112/150
# Progress: 113/150
# Progress: 114/150
# Progress: 115/150
# Progress: 116/150
# Progress: 117/150
# Progress: 118/150
# Progress: 119/150
#  x out failed
# Progress: 120/150
# Progress: 121/150
# Progress: 122/150
# Progress: 123/150
# Progress: 124/150
# Progress: 125/150
# Progress: 126/150
# Progress: 127/150
# Progress: 128/150
# Progress: 129/150
# Progress: 130/150
# Progress: 131/150
# Progress: 132/150
# Progress: 133/150
# Progress: 134/150
# Progress: 135/150
# Progress: 136/150
# Progress: 137/150
# Progress: 138/150
# Progress: 139/150
# Progress: 140/150
# Progress: 141/150
# Progress: 142/150
# Progress: 143/150
# Progress: 144/150
# Progress: 145/150
# Progress: 146/150
# Progress: 147/150
# Progress: 148/150
# Progress: 149/150

# %%
df.head(50)
# Out:
#                                             Job Title  \
# 0                               Junior Data Scientist
# 1                               Junior Data Scientist
# 2                 Data Scientist – Revenue Management
# 3                                      Data Scientist
# 4                            Analytics Data Scientist
# 5                                      Data Scientist
# 6   SENIOR MANAGER, DATA & ARTIFICIAL INTELLIGENCE...
# 7                        Lead Data Scientist (Hybrid)
# 8                  Data Science and Analytics Manager
# 9                           Machine Learning Engineer
# 10                      Senior Data Analyst (PowerBI)
# 11  Instructor: Artificial Intelligence & Data Sci...
# 12                             Applied Data Scientist
# 13                                     Data Scientist
# 14               Data Science Specialist, Investments
# 15                               Staff Data Scientist
# 16                     Data Scientist (Deep Learning)
# 17                                     Data Scientist
# 18                                Senior Data Analyst
# 19                                   Sr. Data Analyst
# 20                                 Data Lead (Remote)
# 21            Junior Software Developer: Data Science
# 22           Data Visualization and Analytics Advisor
# 23                             Data Analytics Advisor
# 24                          STATISTICAL ANALYST - UBC
# 25                                               None
# 26                                       Data Analyst
# 27                                     Data Scientist
# 28                                Data Scientist Lead
# 29                              Data Scientist Intern
# 30  Machine Learning Research Scientist - Biotechn...
# 31                                     Data Scientist
# 32                                 Jr. Data Scientist
# 33                              Senior Data Scientist
# 34                               Data Science Student
# 35     Data Scientist - Data Operations and Analytics
# 36                            Data Scientist (remote)
# 37                             Data Scientist - Marks
# 38                 Statistical Analyst - Data Science
# 39                                       Data Analyst
# 40                                     Data Scientist
# 41                                     Data Scientist
# 42                     Data Analyst/Scientist (Co-op)
# 43                                               None
# 44               Business Data Scientist Co-Op/Intern
# 45                                     Data Scientist
# 46                                     Data Scientist
# 47                                     Data Scientist
# 48                      Data Scientist (Co-Op) Canada
# 49                     Data Scientist - Remote Canada
#
#                        Salary Estimate  \
# 0     CA$74K - CA$90K (Glassdoor est.)
# 1               CA$11K (Employer est.)
# 2     CA$84K - CA$96K (Glassdoor est.)
# 3    CA$55K - CA$119K (Glassdoor est.)
# 4     CA$65K - CA$100K (Employer est.)
# 5    CA$85K - CA$120K (Glassdoor est.)
# 6     CA$67K - CA$93K (Glassdoor est.)
# 7    CA$56K - CA$108K (Glassdoor est.)
# 8     CA$76K - CA$88K (Glassdoor est.)
# 9     CA$60K - CA$98K (Glassdoor est.)
# 10                                  -1
# 11   CA$80K - CA$121K (Glassdoor est.)
# 12              CA$55K (Employer est.)
# 13                                  -1
# 14   CA$89K - CA$108K (Glassdoor est.)
# 15                                  -1
# 16   CA$135K - CA$150K (Employer est.)
# 17  CA$134K - CA$191K (Glassdoor est.)
# 18   CA$63K - CA$119K (Glassdoor est.)
# 19    CA$44K - CA$53K (Glassdoor est.)
# 20    CA$49K - CA$58K (Glassdoor est.)
# 21     CA$55K - CA$75K (Employer est.)
# 22    CA$45K - CA$78K (Glassdoor est.)
# 23                                  -1
# 24    CA$35.98 Per Hour(Employer est.)
# 25   CA$50K - CA$105K (Glassdoor est.)
# 26                                  -1
# 27                                  -1
# 28   CA$71K - CA$125K (Glassdoor est.)
# 29                                  -1
# 30    CA$90K - CA$110K (Employer est.)
# 31   CA$100K - CA$150K (Employer est.)
# 32   CA$76K - CA$119K (Glassdoor est.)
# 33  CA$112K - CA$129K (Glassdoor est.)
# 34    CA$55K - CA$75K (Glassdoor est.)
# 35   CA$96K - CA$115K (Glassdoor est.)
# 36   CA$80K - CA$121K (Glassdoor est.)
# 37   CA$82K - CA$101K (Glassdoor est.)
# 38    CA$64K - CA$73K (Glassdoor est.)
# 39                                  -1
# 40   CA$86K - CA$111K (Glassdoor est.)
# 41    CA$53K - CA$61K (Glassdoor est.)
# 42                                  -1
# 43     CA$70K - CA$80K (Employer est.)
# 44    CA$87K - CA$96K (Glassdoor est.)
# 45   CA$63K - CA$120K (Glassdoor est.)
# 46    CA$49K - CA$57K (Glassdoor est.)
# 47   CA$66K - CA$105K (Glassdoor est.)
# 48   CA$97K - CA$113K (Glassdoor est.)
# 49    CA$54K - CA$88K (Glassdoor est.)
#
#                                       Job Description Rating  \
# 0   We are looking for our next Junior Data Scient...    3.9
# 1   We are looking for our next Junior Data Scient...    3.9
# 2   Powered by water... and by people like you\n\n...     -1
# 3   Join our Winning Team as a Data Scientist\nWhe...    4.5
# 4   BrainFinance is a leading financial technology...     -1
# 5   Referred applicants should not apply directly ...    3.6
# 6   Location: Pickering, ON, CA, L1W 3J2\nReq ID: ...    4.2
# 7   Job Category:\nProperty Tax, Software\nOpportu...    4.0
# 8   Data Science Manager\nGALE is a creative media...    3.7
# 9   Charger Logistics is a world class asset-based...    3.5
# 10  OMERS Products and Technology is looking for D...    4.0
# 11  Job Description\nToronto Business College is a...    4.1
# 12  Position\nApplied Data Scientist\nReporting to...     -1
# 13  Are you looking to join a dynamic pension plan...    4.0
# 14  Job Description :\nAbout Us\n\nAmica Senior Li...    3.6
# 15  Staff Data Scientist\n\nMust Have:\n\n7+ years...    4.6
# 16  Le Data Scientist (Deep Learning) fera partie ...    5.0
# 17  As a Data Scientist, you’ll bring a deep under...     -1
# 18  Job ID #350217\nSenior Data Analyst\nOn behalf...    3.9
# 19  Title: Sr. Data Analyst\n\nLocation: Greater T...    3.9
# 20  Data Lead (Remote) Ref # VS1114223\nThe Career...    4.3
# 21  About Us\nCopperstone helps mining companies m...    5.0
# 22  Manpower is currently seeking a Data Visualiza...    4.1
# 23  Adecco is currently hiring for a full-time Dat...     -1
# 24  Recruiting in Motion is a successful and dynam...    4.4
# 25                                               None     -1
# 26  Job#: 1311483\n\nJob Description:\nData Analys...    3.9
# 27  Data Scientist/ Analyst - PHD Required\nVancou...    5.0
# 28  Job ID #349220\nData Scientist Lead\nOn behalf...    3.9
# 29  Binance is the global blockchain company behin...    3.6
# 30  This is a leading company in artificial intell...    4.4
# 31  A special note from Mark Hobbs, CEO and Rachel...     -1
# 32  SimpTek Technologies - Fredericton, NB:\nSimpT...    4.9
# 33  Our Purpose\nWe work to connect and power an i...    4.3
# 34  The future you want is within reach.\n\nAt PCL...    4.1
# 35  Location: Toronto, ON, CA Edmonton, AB, CA Cal...    3.9
# 36  Company Description\n\nYou will join a world-c...    5.0
# 37  Help us boldly shape retail in Canada\nCanadia...    3.7
# 38  Individually we are people, but together we ar...    3.9
# 39  Data Analyst\n\nNew Grad / Entry Level\n\nAre ...    4.1
# 40  Company Description\n\nAs a trusted partner to...    5.0
# 41  Job Description:\nThe Company:\nHere at Rakute...    3.4
# 42  Location: Remote Canada, Canada\nThales people...    3.6
# 43                                               None     -1
# 44  At Kinaxis, who we are is grounded in our comm...    4.5
# 45  Data Scientist\n\nGranify is a rapidly growing...    4.5
# 46  A little bit about GeoComply\n\nAt GeoComply, ...    4.3
# 47  Come Work with Us!\n\nAt RBC, our culture is d...    4.0
# 48  What You’ll Do\nAcquire, clean and structure d...    4.3
# 49  Data Scientist - Remote Canada\nAs a Data Scie...    4.8
#
#                                Company Name Division     Location  \
# 0                      M&M Food Market\n3.9     None  Mississauga
# 1                      M&M Food Market\n3.9     None  Mississauga
# 2                             BC Hydro\n3.8     None    Vancouver
# 3                               Carfax\n4.5     None       London
# 4                             Brain Finance     None     Montreal
# 5             Loblaw Companies Limited\n3.6     None     Brampton
# 6             Ontario Power Generation\n4.2     None    Pickering
# 7                          Altus Group\n4.0     None      Toronto
# 8                        GALE Partners\n3.7     None      Toronto
# 9                Charger Logistics Inc\n3.5     None     Brampton
# 10                               OMERS\n4.0     None      Toronto
# 11            TORONTO BUSINESS COLLEGE\n4.1     None   North York
# 12                                   Airudi     None       Remote
# 13                               OMERS\n4.0     None      Toronto
# 14             Amica Senior Lifestyles\n3.6     None      Toronto
# 15                      ISG Search Inc\n4.6     None      Toronto
# 16  DELAN - Chasseurs de Talents en TI\n5.0     None     Montreal
# 17                               Maarut Inc     None      Calgary
# 18                              Procom\n3.9     None      Toronto
# 19             Drake International Inc\n3.9     None      Toronto
# 20               The Career Foundation\n4.3     None      Toronto
# 21       Copperstone Technologies Ltd.\n5.0     None     Edmonton
# 22                            Manpower\n4.1     None      Calgary
# 23                       Adecco Canada\n3.7     None      Calgary
# 24                Recruiting in Motion\n4.4     None    Vancouver
# 25                                     None     None         None
# 26                        Apex Systems\n3.9     None  Mississauga
# 27     TalentSphere Staffing Solutions\n5.0     None      Toronto
# 28                              Procom\n3.9     None    Vancouver
# 29                             Binance\n3.6     None       Canada
# 30                    Groom & Associes\n4.4     None     Montreal
# 31                               Fundmetric     None      Halifax
# 32                SimpTek Technologies\n4.9     None  Fredericton
# 33                          Mastercard\n4.3     None    Vancouver
# 34                    PCL Construction\n4.1     None     Edmonton
# 35                               TELUS\n3.9     None      Toronto
# 36                  Ample Insight Inc.\n5.0     None      Toronto
# 37                              Mark's\n3.7     None      Calgary
# 38                               Aviva\n3.7     None      Toronto
# 39             THE EMPIRE LIFE INS. CO\n4.1     None       Canada
# 40                              Points\n5.0     None      Toronto
# 41                             Rakuten\n5.0     None      Toronto
# 42                              Thales\n3.5     None       Remote
# 43                                     None     None         None
# 44                             Kinaxis\n4.5     None      Toronto
# 45                             Granify\n4.5     None     Edmonton
# 46                           GeoComply\n4.3     None    Vancouver
# 47                Royal Bank of Canada\n4.1     None      Toronto
# 48                       Cisco Systems\n4.3     None      Toronto
# 49                        TTEC Digital\n4.8     None       London
#
#                        Size Founded               Type of ownership  \
# 0    1001 to 5000 Employees    None               Company - Private
# 1    1001 to 5000 Employees    None               Company - Private
# 2    1001 to 5000 Employees    None                   Self-employed
# 3    1001 to 5000 Employees    1984                Company - Public
# 4                   Unknown    None               Company - Private
# 5          10000+ Employees    None                Company - Public
# 6   5001 to 10000 Employees    1999                      Government
# 7    1001 to 5000 Employees    2005                Company - Public
# 8     501 to 1000 Employees    2014               Company - Private
# 9    1001 to 5000 Employees    2005               Company - Private
# 10   1001 to 5000 Employees    1962               Company - Private
# 11        1 to 50 Employees    None            College / University
# 12                     None    None                            None
# 13   1001 to 5000 Employees    1962               Company - Private
# 14   1001 to 5000 Employees    1996               Company - Private
# 15        1 to 50 Employees    1990               Company - Private
# 16        1 to 50 Employees    1997               Company - Private
# 17      51 to 200 Employees    None         Private Practice / Firm
# 18  5001 to 10000 Employees    1978               Company - Private
# 19   1001 to 5000 Employees    1951               Company - Private
# 20        1 to 50 Employees    None          Nonprofit Organization
# 21        1 to 50 Employees    None               Company - Private
# 22         10000+ Employees    1948  Subsidiary or Business Segment
# 23    501 to 1000 Employees    None  Subsidiary or Business Segment
# 24      51 to 200 Employees    2010               Company - Private
# 25                     None    None                            None
# 26   1001 to 5000 Employees    1995                Company - Public
# 27        1 to 50 Employees    2013               Company - Private
# 28  5001 to 10000 Employees    1978               Company - Private
# 29  5001 to 10000 Employees    2017               Company - Private
# 30        1 to 50 Employees    None               Company - Private
# 31                     None    None                            None
# 32        1 to 50 Employees    None               Company - Private
# 33         10000+ Employees    1966                Company - Public
# 34   1001 to 5000 Employees    1906               Company - Private
# 35         10000+ Employees    1998                Company - Public
# 36        1 to 50 Employees    None               Company - Private
# 37  5001 to 10000 Employees    1977               Company - Private
# 38        1 to 50 Employees    None               Company - Private
# 39    501 to 1000 Employees    1923               Company - Private
# 40                  Unknown    None               Company - Private
# 41         10000+ Employees    1997                Company - Public
# 42   1001 to 5000 Employees    2000                Company - Public
# 43     201 to 500 Employees    None               Company - Private
# 44    501 to 1000 Employees    1984                Company - Public
# 45      51 to 200 Employees    2010               Company - Private
# 46    501 to 1000 Employees    2011               Company - Private
# 47         10000+ Employees    1869                Company - Public
# 48         10000+ Employees    1984                Company - Public
# 49   1001 to 5000 Employees    2011               Company - Private
#
#                                    Industry  \
# 0                         Animal Production
# 1                         Animal Production
# 2                        Energy & Utilities
# 3                   Internet & Web Services
# 4                                      None
# 5                           Vehicle Dealers
# 6                        Energy & Utilities
# 7                               Real Estate
# 8            Advertising & Public Relations
# 9                       Taxi & Car Services
# 10            Investment & Asset Management
# 11                                     None
# 12                                     None
# 13            Investment & Asset Management
# 14         Health Care Services & Hospitals
# 15  Information Technology Support Services
# 16  Information Technology Support Services
# 17  Information Technology Support Services
# 18                            HR Consulting
# 19                            HR Consulting
# 20                            HR Consulting
# 21                                     None
# 22                            HR Consulting
# 23                            HR Consulting
# 24                            HR Consulting
# 25                                     None
# 26  Enterprise Software & Network Solutions
# 27                            HR Consulting
# 28                            HR Consulting
# 29                  Internet & Web Services
# 30                            HR Consulting
# 31                                     None
# 32                                     None
# 33         Financial Transaction Processing
# 34                             Construction
# 35    Cable, Internet & Telephone Providers
# 36                                     None
# 37       Department, Clothing & Shoe Stores
# 38                          Mining & Metals
# 39                       Insurance Carriers
# 40                                     None
# 41                  Internet & Web Services
# 42                      Aerospace & Defense
# 43                                     None
# 44  Enterprise Software & Network Solutions
# 45  Information Technology Support Services
# 46  Enterprise Software & Network Solutions
# 47                        Banking & Lending
# 48  Enterprise Software & Network Solutions
# 49  Information Technology Support Services
#
#                                          Sector  \
# 0                                   Agriculture
# 1                                   Agriculture
# 2                    Energy, Mining & Utilities
# 3                        Information Technology
# 4                                          None
# 5                            Retail & Wholesale
# 6                    Energy, Mining & Utilities
# 7                                   Real Estate
# 8                         Media & Communication
# 9                    Transportation & Logistics
# 10                           Financial Services
# 11                                         None
# 12                                         None
# 13                           Financial Services
# 14                                   Healthcare
# 15                       Information Technology
# 16                       Information Technology
# 17                       Information Technology
# 18                   Human Resources & Staffing
# 19                   Human Resources & Staffing
# 20                   Human Resources & Staffing
# 21                                         None
# 22                   Human Resources & Staffing
# 23                   Human Resources & Staffing
# 24                   Human Resources & Staffing
# 25                                         None
# 26                       Information Technology
# 27                   Human Resources & Staffing
# 28                   Human Resources & Staffing
# 29                       Information Technology
# 30                   Human Resources & Staffing
# 31                                         None
# 32                                         None
# 33                           Financial Services
# 34  Construction, Repair & Maintenance Services
# 35                           Telecommunications
# 36                                         None
# 37                           Retail & Wholesale
# 38                   Energy, Mining & Utilities
# 39                                    Insurance
# 40                                         None
# 41                       Information Technology
# 42                          Aerospace & Defense
# 43                                         None
# 44                       Information Technology
# 45                       Information Technology
# 46                       Information Technology
# 47                           Financial Services
# 48                       Information Technology
# 49                       Information Technology
#
#                              Revenue
# 0          $25 to $100 million (USD)
# 1          $25 to $100 million (USD)
# 2           Unknown / Non-Applicable
# 3           Unknown / Non-Applicable
# 4           Unknown / Non-Applicable
# 5                 $10+ billion (USD)
# 6             $1 to $5 billion (USD)
# 7         $100 to $500 million (USD)
# 8           Unknown / Non-Applicable
# 9            $5 to $25 million (USD)
# 10          Unknown / Non-Applicable
# 11          Unknown / Non-Applicable
# 12                              None
# 13          Unknown / Non-Applicable
# 14         $25 to $100 million (USD)
# 15          Unknown / Non-Applicable
# 16            $1 to $5 million (USD)
# 17          Unknown / Non-Applicable
# 18            $1 to $5 billion (USD)
# 19          Unknown / Non-Applicable
# 20            $1 to $5 million (USD)
# 21          Unknown / Non-Applicable
# 22                $10+ billion (USD)
# 23         $25 to $100 million (USD)
# 24          Unknown / Non-Applicable
# 25                              None
# 26            $1 to $5 billion (USD)
# 27            $1 to $5 million (USD)
# 28            $1 to $5 billion (USD)
# 29            $1 to $5 billion (USD)
# 30            $1 to $5 million (USD)
# 31                              None
# 32          Unknown / Non-Applicable
# 33           $5 to $10 billion (USD)
# 34           $5 to $10 billion (USD)
# 35                $10+ billion (USD)
# 36          Unknown / Non-Applicable
# 37  $500 million to $1 billion (USD)
# 38          Unknown / Non-Applicable
# 39            $1 to $5 billion (USD)
# 40          Unknown / Non-Applicable
# 41                $10+ billion (USD)
# 42            $1 to $5 billion (USD)
# 43           $5 to $25 million (USD)
# 44        $100 to $500 million (USD)
# 45          Unknown / Non-Applicable
# 46          Unknown / Non-Applicable
# 47                $10+ billion (USD)
# 48                $10+ billion (USD)
# 49          Unknown / Non-Applicable

# %%
df.dtypes
# Out:
# Job Title            object
# Salary Estimate      object
# Job Description      object
# Rating               object
# Company Name         object
# Division             object
# Location             object
# Size                 object
# Founded              object
# Type of ownership    object
# Industry             object
# Sector               object
# Revenue              object
# dtype: object
